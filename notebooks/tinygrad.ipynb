# %%
from tinygrad import Tensor
import numpy as np

# %%
x = Tensor.eye(3, requires_grad=True)
y = Tensor([[2.0,0,-2.0]], requires_grad=True)
z = y.matmul(x).sum()
z.backward()

print(x.grad.numpy())  # dz/dx
print(y.grad.numpy())  # dz/dy
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 6
#       3 z = y.matmul(x).sum()
#       4 z.backward()
# ----> 6 print(x.grad.numpy())  # dz/dx
#       7 print(y.grad.numpy())  # dz/dy
#
# File ~/Projects/tinygrad/tinygrad/tensor.py:176, in Tensor.numpy(self)
#     174 assert self.dtype.np is not None, f"no np dtype for {self.dtype}"
#     175 assert all_int(self.shape), f"no data if shape is symbolic, {self.shape=}"
# --> 176 return np.frombuffer(self._data(), dtype=self.dtype.np).reshape(self.shape)
#
# File ~/Projects/tinygrad/tinygrad/tensor.py:163, in Tensor._data(self)
#     161 if 0 in self.shape: return memoryview(bytearray(0))
#     162 t = self if isinstance(self.device, str) else self.to(self.device[0])   # deal with multitensor
# --> 163 return cast(Buffer, t.cast(t.dtype.scalar()).contiguous().realize().lazydata.base.realized).as_buffer()
#
# File ~/Projects/tinygrad/tinygrad/tensor.py:135, in Tensor.realize(self)
#     134 def realize(self) -> Tensor:
# --> 135   Tensor.corealize([self])
#     136   return self
#
# File ~/Projects/tinygrad/tinygrad/tensor.py:132, in Tensor.corealize(lst)
#     130 @staticmethod
#     131 def corealize(lst:Iterable[Tensor]):
# --> 132   run_schedule(create_schedule(flatten([x.lazydata.lbs if isinstance(x.lazydata, MultiLazyBuffer) else [x.lazydata] for x in lst])))
#
# File ~/Projects/tinygrad/tinygrad/realize.py:56, in run_schedule(schedule)
#      53 if logops and si.ast.op not in LoadOps and not any(i.device.startswith("DISK:") for i in si.inputs): logops.write(str(si.ast)+"\n")
#      55 # get the program
# ---> 56 prg = lower_schedule_item(si)
#      58 # invalidate the output buffer if there's a non contig usage of it in inputs
#      59 if si.out.output_buffer is not None:
#
# File ~/Projects/tinygrad/tinygrad/realize.py:47, in lower_schedule_item(si)
#      45 if si.ast.op is LoadOps.SYNC: return SyncOp(si.out.device) if isinstance(Device[si.out.device], Compiled) else None
#      46 if si.ast.op is LoadOps.WAIT: return None
# ---> 47 return Device[si.out.device].get_runner(si.ast)
#
# File ~/Projects/tinygrad/tinygrad/device.py:271, in Compiled.get_runner(self, ast)
#     270 @functools.lru_cache(None)    # pylint: disable=method-cache-max-size-none
# --> 271 def get_runner(self, ast:LazyOp) -> CompiledASTRunner: return self.to_program(self.get_linearizer(ast))
#
# File ~/Projects/tinygrad/tinygrad/device.py:241, in Compiled.to_program(self, k)
#     239 run_count = prod((k.global_size if k.global_size else []) + (k.local_size if k.local_size else []))
#     240 # NOTE: we use min here to ignore the indexing FLOPS
# --> 241 ret = CompiledASTRunner(k.name, self.compiler.render(to_function_name(k.name), k.uops), self, k.global_size, k.local_size,
#     242                         k.uops.vars(), min(info.flops, ops * run_count), min(info.mem_estimate, mem * run_count))
#     243 return ret
#
# File ~/Projects/tinygrad/tinygrad/device.py:200, in CompiledASTRunner.__init__(self, name, prg, device, global_size, local_size, variables, op_estimate, mem_estimate, precompiled)
#     198 assert self.device.compiler is not None, "compiler is reuired to make an AST kernel"
#     199 lib:bytes = precompiled if precompiled is not None else self.device.compiler.compile_cached(prg)
# --> 200 self.lib, self.clprg = lib, self.device.runtime(self.name, lib)
#     201 self.vars: List[Variable] = [] if variables is None else variables
#     202 self.op_estimate, self.mem_estimate = op_estimate, mem_estimate
#
# File ~/Projects/tinygrad/tinygrad/runtime/ops_metal.py:41, in MetalProgram.__init__(self, device, name, lib)
#      39     os.system(f"cd {pathlib.Path(__file__).parents[2]}/disassemblers/applegpu && python3 compiler_explorer.py {shader.name}")
#      40 data = libdispatch.dispatch_data_create(lib, len(lib), None, None)
# ---> 41 self.library = unwrap2(self.device.device.newLibraryWithData_error_(data, None))
#      42 self.fxn = self.library.newFunctionWithName_(name)
#      43 self.pipeline_state = unwrap2(self.device.device.newComputePipelineStateWithFunction_error_(self.fxn, None))
#
# File ~/Projects/tinygrad/tinygrad/helpers.py:50, in unwrap2(x)
#      48 def unwrap2(x:Tuple[T,Any]) -> T:
#      49   ret, err = x
# ---> 50   assert err is None, str(err)
#      51   return ret
#
# AssertionError: Error Domain=MTLLibraryErrorDomain Code=1 "Invalid library file" UserInfo={NSLocalizedDescription=Invalid library file}
